# %%
import pandas as pd

df = pd.read_csv("E:/learning/AI1/python/Python-Pandas/1.0 Introduction/temperature.csv")

print(df['AverageTemperatureFahr'].max())
# Out:
# 65.4764

# %%
R,C = df.shape
print(R, C)
# Out:
# 82 11

# %%
#print(df.head)

# %%
df[1:9]
# Out:
#    record_id  month  day  year  AverageTemperatureFahr  \
# 1     474377      2    1  1853                     NaN
# 2     474378      3    1  1853                     NaN
# 3     474379      4    1  1853                     NaN
# 4     474380      5    1  1853                     NaN
# 5     474381      6    1  1853                 51.9062
# 6     474382      7    1  1853                 52.3886
# 7     474383      8    1  1853                 52.8530
# 8     474384      9    1  1853                 52.5776
#
#    AverageTemperatureUncertaintyFahr      City country_id      Country  \
# 1                                NaN  Auckland        NEW  New Zealand
# 2                                NaN  Auckland        NEW  New Zealand
# 3                                NaN  Auckland        NEW  New Zealand
# 4                                NaN  Auckland        NEW  New Zealand
# 5                            36.9572  Auckland        NEW  New Zealand
# ...

# %%
type(df['AverageTemperatureFahr'])
# Out:
# pandas.core.series.Series

# %%
df[['year','AverageTemperatureFahr']]
# Out:
#     year  AverageTemperatureFahr
# 0   1853                     NaN
# 1   1853                     NaN
# 2   1853                     NaN
# 3   1853                     NaN
# 4   1853                     NaN
# ..   ...                     ...
# 77  1859                 54.3794
# 78  1859                 52.7036
# 79  1859                 51.8900
# 80  1859                 52.3202
# 81  1859                 57.3152
#
# [82 rows x 2 columns]

# %%
df.describe()
# Out:
#            record_id      month   day         year  AverageTemperatureFahr  \
# count      82.000000  82.000000  82.0    82.000000               77.000000
# mean   474416.500000   6.378049   1.0  1855.926829               57.271930
# std        23.815261   3.423377   0.0     1.980027                4.452425
# min    474376.000000   1.000000   1.0  1853.000000               50.930600
# 25%    474396.250000   3.250000   1.0  1854.000000               53.191400
# 50%    474416.500000   6.000000   1.0  1856.000000               56.688800
# 75%    474436.750000   9.000000   1.0  1858.000000               61.584800
# max    474457.000000  12.000000   1.0  1859.000000               65.476400
#
#        AverageTemperatureUncertaintyFahr
# count                          77.000000
# mean                           35.439332
# std                             1.585093
# min                            33.292400
# 25%                            34.230200
# 50%                            35.002400
# ...

# %%
df[df['month'] > 10]
# Out:
#     record_id  month  day  year  AverageTemperatureFahr  \
# 10     474386     11    1  1853                 56.6888
# 11     474387     12    1  1853                 59.8460
# 22     474398     11    1  1854                 57.3170
# 23     474399     12    1  1854                 60.0296
# 34     474410     11    1  1855                 58.1558
# 35     474411     12    1  1855                 60.9206
# 46     474422     11    1  1856                 55.5854
# 47     474423     12    1  1856                 63.7466
# 58     474434     11    1  1857                 56.4602
# 59     474435     12    1  1857                 59.5634
# 70     474446     11    1  1858                 57.2540
# 71     474447     12    1  1858                 62.2760
#
#     AverageTemperatureUncertaintyFahr      City country_id      Country  \
# 10                            34.2518  Auckland        NEW  New Zealand
# 11                            37.5062  Auckland        NEW  New Zealand
# ...

# %%
df[['year','AverageTemperatureFahr']][df.year == df['year'].max()]
# Out:
#     year  AverageTemperatureFahr
# 72  1859                 64.5872
# 73  1859                 65.4764
# 74  1859                 63.0788
# 75  1859                 61.0160
# 76  1859                 57.4070
# 77  1859                 54.3794
# 78  1859                 52.7036
# 79  1859                 51.8900
# 80  1859                 52.3202
# 81  1859                 57.3152

# %%
df.index
# Out:
# RangeIndex(start=0, stop=82, step=1)

# %% [markdown]
# # Not updating the original data frame

# %%
df.set_index('year')
# Out:
#       record_id  month  day  AverageTemperatureFahr  \
# year
# 1853     474376      1    1                     NaN
# 1853     474377      2    1                     NaN
# 1853     474378      3    1                     NaN
# 1853     474379      4    1                     NaN
# 1853     474380      5    1                     NaN
# ...         ...    ...  ...                     ...
# 1859     474453      6    1                 54.3794
# 1859     474454      7    1                 52.7036
# 1859     474455      8    1                 51.8900
# 1859     474456      9    1                 52.3202
# 1859     474457     10    1                 57.3152
#
#       AverageTemperatureUncertaintyFahr      City country_id      Country  \
# year
# 1853                                NaN  Auckland        NEW  New Zealand
# 1853                                NaN  Auckland        NEW  New Zealand
# 1853                                NaN  Auckland        NEW  New Zealand
# ...

# %% [markdown]
# #  Updating the original data frame

# %%
df.set_index('year', inplace=True)

# %%
df.loc['1853']
# Out:
#       record_id  month  day  AverageTemperatureFahr  \
# year
# 1853     474376      1    1                     NaN
# 1853     474377      2    1                     NaN
# 1853     474378      3    1                     NaN
# 1853     474379      4    1                     NaN
# 1853     474380      5    1                     NaN
# 1853     474381      6    1                 51.9062
# 1853     474382      7    1                 52.3886
# 1853     474383      8    1                 52.8530
# 1853     474384      9    1                 52.5776
# 1853     474385     10    1                 54.8726
# 1853     474386     11    1                 56.6888
# 1853     474387     12    1                 59.8460
#
#       AverageTemperatureUncertaintyFahr      City country_id      Country  \
# year
# 1853                                NaN  Auckland        NEW  New Zealand
# 1853                                NaN  Auckland        NEW  New Zealand
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#     year  record_id  month  day  AverageTemperatureFahr  \
# 0   1853     474376      1    1                     NaN
# 1   1853     474377      2    1                     NaN
# 2   1853     474378      3    1                     NaN
# 3   1853     474379      4    1                     NaN
# 4   1853     474380      5    1                     NaN
# ..   ...        ...    ...  ...                     ...
# 77  1859     474453      6    1                 54.3794
# 78  1859     474454      7    1                 52.7036
# 79  1859     474455      8    1                 51.8900
# 80  1859     474456      9    1                 52.3202
# 81  1859     474457     10    1                 57.3152
#
#     AverageTemperatureUncertaintyFahr      City country_id      Country  \
# 0                                 NaN  Auckland        NEW  New Zealand
# 1                                 NaN  Auckland        NEW  New Zealand
# 2                                 NaN  Auckland        NEW  New Zealand
# ...
